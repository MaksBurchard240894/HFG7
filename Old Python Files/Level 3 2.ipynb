# %%
listxs = []
listys = []
listns = []
listxsint = []
listysint = []

with open("level3_exampletext.txt", "r") as levellist:
	lines = levellist.readlines()

for l in lines:
	as_list = l.split(" ")
	listxs.append(as_list[0])
	listys.append(as_list[1])
	listns.append(as_list[2])

for s in listxs:
    listxsint.append(int(s))

for s in listys:
    listysint.append(int(s))
    
a = 1
b = 0
c = 0
d = 0
e = 0
f = 0
g = 0
h = 0
rangeList = 0
lastNumber = 0


for z in listxsint:
    a = 1
    x = listxsint[b]
    y = listysint[c]
    n = x/3*y
    b = b+1
    c = c+1
    f = 0

    if x % 3 == 0:
        for i in range(int(n*3+1)):
            if i == 0:
                pass
            else:
                print (a, end = " ") 
                if i % 3 == 0:
                    a = a+1
                if i % x == 0:
                    print (" ")

    if x % 3 == 1:
        for i in range(int(n*3+2-y)):
            if i == 0:
                pass
            else:
                if (i + f) % x == 0:
                    f = f + 1
                    if g % y >= 3:
                        if i == lastNumber:
                            print(0)
                        else:
                            print(0)
                            print(a, end = " ")
                    else:
                        if e == 0:
                            d = a
                            print (d)
                            a = d + 1
                            print (a, end = " ")
                            e = e + 1
                        else:
                            print(d)
                            e = e + 1
                            print (a, end = " ")
                            if e == 3:
                                e = 0
                                g = g + 3
                else:
                    print (a, end = " ") 
                    if i % 3 == 0:
                        a = a + 1
# Out:
# 1 1 1 2 2 2 3
# 4 4 4 5 5 5 3
# 6 6 6 7 7 7 3
# 8 8 8 9 9 9 0
# 10 10 10 11 11 11 0
# 12 1 1 1 2 2 2 3 3 3
# 4 4 4 5 5 5 6 6 6
# 7 7 7 8 8 8 9 9 9
# 10 10 10 11 11 11 12 12 12
# 13 13 13 14 14 14 15 15 15
# 16 16 16 17 17 17 18 18 18
# 19 19 19 20 20 20 21 21 21
# 1 1 1 2 2 2
# 3 3 3 4 4 4
# 5 5 5 6 6 6
# 7 7 7 8 8 8
# 9 9 9 10 10 10
# 11 11 11 12 12 12
# 13 13 13 14 14 14
# 15 15 15 16 16 16

# %%
1 + 1


7 + 0

(7 + 0) % 7

3/5
# Out:
# 0.6
