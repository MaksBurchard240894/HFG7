# %%
x = 9
y = 8
n = x/3*y
a = 1

for i in range(int(n*3+1)):
  print (a, end=" ") 
  if i !=0 and i % 3 == 0:
        a = a+1
  if i % x == 0:
      print (" ")
# Out:
# 1
# 1 1 1 2 2 2 3 3 3
# 4 4 4 5 5 5 6 6 6
# 7 7 7 8 8 8 9 9 9
# 10 10 10 11 11 11 12 12 12
# 13 13 13 14 14 14 15 15 15
# 16 16 16 17 17 17 18 18 18
# 19 19 19 20 20 20 21 21 21
# 22 22 22 23 23 23 24 24 24

# %%
filex = open("level2_1x.txt", "r")
print(file.read())

print(" ")

filey = open("level2_1y.txt", "r")
print(filey.read())

print(" ")

filey = open("level2_1y.txt", "r")
print(filey.read(10))
something = filey.split("\n")
# Out:
#
# 9
# 16
# 17
# 13
# 5
# 10
# 4
# 12
# 9
# 10
#
# 9
# 16
# 17
# 13
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 13
#      11 filey = open("level2_1y.txt", "r")
#      12 print(filey.read(10))
# ---> 13 something = filey.split("\n")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
listy = []
listyint = []

with open("level2_1y.txt", "r") as ylist:
	lines = ylist.readlines()
	print(lines)

for l in lines:
	as_list = l.split(", ")
	listy.append(as_list[0].replace("\n", ""))

for s in listy:
    listyint.append(int(s))

print(listyint)
# Out:
# ['9\n', '16\n', '17\n', '13\n', '5\n', '10\n', '4\n', '12\n', '9\n', '10']
# [9, 16, 17, 13, 5, 10, 4, 12, 9, 10]

# %%
listx = []
listxint = []

with open("level2_1x.txt", "r") as xlist:
	lines = xlist.readlines()
	print(lines)

for l in lines:
	as_list = l.split(", ")
	listx.append(as_list[0].replace("\n", ""))

for s in listx:
    listxint.append(int(s))

print(listxint)
# Out:
# ['15\n', '9\n', '12\n', '6\n', '9\n', '18\n', '9\n', '12\n', '15\n', '18']
# [15, 9, 12, 6, 9, 18, 9, 12, 15, 18]

# %%
listxs = []
listys = []
listns = []
listxsint = []
listysint = []

with open("level2_2text.txt", "r") as levellist:
	lines = levellist.readlines()
	print(lines)

for l in lines:
	as_list = l.split(" ")
	listxs.append(as_list[0])
	listys.append(as_list[1])
	listns.append(as_list[2])

print(listxs)
print(listys)
print(listns)

for s in listxs:
    listxsint.append(int(s))

print(listxsint)

for s in listys:
    listysint.append(int(s))
    
print(listysint)
# Out:
# ['12 16 64\n', '18 15 90\n', '18 16 96\n', '6 16 32\n', '9 7 21\n', '9 6 18\n', '15 8 40\n', '9 16 48\n', '12 18 72\n', '12 9 36\n']
# ['12', '18', '18', '6', '9', '9', '15', '9', '12', '12']
# ['16', '15', '16', '16', '7', '6', '8', '16', '18', '9']
# ['64\n', '90\n', '96\n', '32\n', '21\n', '18\n', '40\n', '48\n', '72\n', '36\n']
# [12, 18, 18, 6, 9, 9, 15, 9, 12, 12]
# [16, 15, 16, 16, 7, 6, 8, 16, 18, 9]

# %%
listx = []
listxint = []

with open("level2_1x.txt", "r") as xlist:
	lines = xlist.readlines()

for l in lines:
	as_list = l.split(", ")
	listx.append(as_list[0].replace("\n", ""))

for s in listx:
    listxint.append(int(s))

print(listxint)

listy = []
listyint = []

with open("level2_1y.txt", "r") as ylist:
	lines = ylist.readlines()

for l in lines:
	as_list = l.split(", ")
	listy.append(as_list[0].replace("\n", ""))

for s in listy:
    listyint.append(int(s))

print(listyint)

a = 1
b = 0
c = 0

for z in listxint:
    a = 1
    x = listxint[b]
    y = listyint[c]
    n = x/3*y
    b = b+1
    c = c+1

    for i in range(int(n*3+1)):
        if i == 0:
            pass
        else:
            print (a, end=" ") 
            if i !=0 and i % 3 == 0:
                a = a+1
            if i % x == 0:
                print (" ")
# Out:
# [15, 9, 12, 6, 9, 18, 9, 12, 15, 18]
# [9, 16, 17, 13, 5, 10, 4, 12, 9, 10]
# 1 1 1 2 2 2 3 3 3 4 4 4 5 5 5
# 6 6 6 7 7 7 8 8 8 9 9 9 10 10 10
# 11 11 11 12 12 12 13 13 13 14 14 14 15 15 15
# 16 16 16 17 17 17 18 18 18 19 19 19 20 20 20
# 21 21 21 22 22 22 23 23 23 24 24 24 25 25 25
# 26 26 26 27 27 27 28 28 28 29 29 29 30 30 30
# 31 31 31 32 32 32 33 33 33 34 34 34 35 35 35
# 36 36 36 37 37 37 38 38 38 39 39 39 40 40 40
# 41 41 41 42 42 42 43 43 43 44 44 44 45 45 45
# 1 1 1 2 2 2 3 3 3
# 4 4 4 5 5 5 6 6 6
# 7 7 7 8 8 8 9 9 9
# 10 10 10 11 11 11 12 12 12
# 13 13 13 14 14 14 15 15 15
# 16 16 16 17 17 17 18 18 18
# 19 19 19 20 20 20 21 21 21
# 22 22 22 23 23 23 24 24 24
# 25 25 25 26 26 26 27 27 27
# 28 28 28 29 29 29 30 30 30
# 31 31 31 32 32 32 33 33 33
# 34 34 34 35 35 35 36 36 36
# 37 37 37 38 38 38 39 39 39
# 40 40 40 41 41 41 42 42 42
# 43 43 43 44 44 44 45 45 45
# 46 46 46 47 47 47 48 48 48
# 1 1 1 2 2 2 3 3 3 4 4 4
# 5 5 5 6 6 6 7 7 7 8 8 8
# 9 9 9 10 10 10 11 11 11 12 12 12
# ...

# %%
listxs = []
listys = []
listns = []
listxsint = []
listysint = []

with open("level2_2text.txt", "r") as levellist:
	lines = levellist.readlines()

for l in lines:
	as_list = l.split(" ")
	listxs.append(as_list[0])
	listys.append(as_list[1])
	listns.append(as_list[2])

for s in listxs:
    listxsint.append(int(s))

for s in listys:
    listysint.append(int(s))
    
a = 1
b = 0
c = 0

for z in listxsint:
    a = 1
    x = listxsint[b]
    y = listysint[c]
    n = x/3*y
    b = b+1
    c = c+1

    for i in range(int(n*3+1)):
        if i == 0:
            pass
        else:
            print (a, end=" ") 
            if i !=0 and i % 3 == 0:
                a = a+1
            if i % x == 0:
                print (" ")
# Out:
# 1 1 1 2 2 2 3 3 3 4 4 4
# 5 5 5 6 6 6 7 7 7 8 8 8
# 9 9 9 10 10 10 11 11 11 12 12 12
# 13 13 13 14 14 14 15 15 15 16 16 16
# 17 17 17 18 18 18 19 19 19 20 20 20
# 21 21 21 22 22 22 23 23 23 24 24 24
# 25 25 25 26 26 26 27 27 27 28 28 28
# 29 29 29 30 30 30 31 31 31 32 32 32
# 33 33 33 34 34 34 35 35 35 36 36 36
# 37 37 37 38 38 38 39 39 39 40 40 40
# 41 41 41 42 42 42 43 43 43 44 44 44
# 45 45 45 46 46 46 47 47 47 48 48 48
# 49 49 49 50 50 50 51 51 51 52 52 52
# 53 53 53 54 54 54 55 55 55 56 56 56
# 57 57 57 58 58 58 59 59 59 60 60 60
# 61 61 61 62 62 62 63 63 63 64 64 64
# 1 1 1 2 2 2 3 3 3 4 4 4 5 5 5 6 6 6
# 7 7 7 8 8 8 9 9 9 10 10 10 11 11 11 12 12 12
# 13 13 13 14 14 14 15 15 15 16 16 16 17 17 17 18 18 18
# 19 19 19 20 20 20 21 21 21 22 22 22 23 23 23 24 24 24
# 25 25 25 26 26 26 27 27 27 28 28 28 29 29 29 30 30 30
# 31 31 31 32 32 32 33 33 33 34 34 34 35 35 35 36 36 36
# 37 37 37 38 38 38 39 39 39 40 40 40 41 41 41 42 42 42
# ...
