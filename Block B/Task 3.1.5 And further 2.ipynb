# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/maksb/OneDrive/Documents/GitHub/2024-25b-fai1-adsai-MaksBurchard240894/Block B/diabetic_data_reg.csv", keep_default_na=False, na_values=["?"])

df.head()
# Out:
# C:\Users\maksb\AppData\Local\Temp\ipykernel_4232\1819032579.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/maksb/OneDrive/Documents/GitHub/2024-25b-fai1-adsai-MaksBurchard240894/Block B/diabetic_data_reg.csv", keep_default_na=False, na_values=["?"])
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# ...

# %%
farm_merge_valley = "fun"

if farm_merge_valley == "fun":
    me = "happy"

# %%
# importing requires sklearn packages for implementing Gradient Boosting Regressor
from sklearn.ensemble import GradientBoostingRegressor

# Initialising and training Gradient Boosting Regressor
gboost_model = GradientBoostingRegressor()


# Predictions
y_pred_gboost = gboost_model.predict(df)

# Evaluation
#mae_gboost = mean_absolute_error()
#mse_gboost = mean_squared_error()

#print(f"Gradient Boosting Regression MAE: {}")
#print(f"Gradient Boosting Regression MSE: {}")
# Out:
# c:\Users\maksb\anaconda3\envs\BlockB\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but GradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4232\1622290430.py in ?()
#       5 gboost_model = GradientBoostingRegressor()
#       6
#       7
#       8 # Predictions
# ----> 9 y_pred_gboost = gboost_model.predict(df)
#      10
#      11 # Evaluation
#      12 #mae_gboost = mean_absolute_error()
#
# c:\Users\maksb\anaconda3\envs\BlockB\Lib\site-packages\sklearn\ensemble\_gb.py in ?(self, X)
#    2123         -------
#    2124         y : ndarray of shape (n_samples,)
#    2125             The predicted values.
#    2126         """
# -> 2127         X = self._validate_data(
# ...
