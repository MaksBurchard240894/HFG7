# %%
print()
choice = 0
question = 0
while question != 10:
  question = question + 1
  if question == 1:
    choice = choice + int(input("Is the goat large and stocky?\n 1 = no, 2 = yes"))
  if question == 2:
    choice = choice + int(input("Does the goat seem to have a hunchback?\n 1 = no, 2 = yes"))
  if question == 3:
    choice = choice + int(input("How large does the goat seem to be?\n 0 = <150lbs 1 = 150-250 lbs, 2 = >250 lbs"))
  if question == 4:
    choice = choice + int(input("Does it have a penis?\n 1 = no, 2 = yes"))
  if question == 5:
    choice = choice + int(input("Is the goat on the edge of a goat group or alone?\n 1 = no, 2 = yes"))
  if question == 6:
    choice = choice + int(input("Does the goat stretch or squat to pee?\n 1 = squat, 2 = stretch"))
  if question == 7:
    choice = choice + int(input("Are the horns thick, close together and don't have a curve at the top?\n 1 = no, 2 = yes"))
  if question == 8:
    choice = choice + int(input("Does the goat seem to exist?\n 1 = no, 2 = yes"))
  if question == 9:
    choice = choice + int(input("Does the goat seem anti-social?\n 1 = no, 2 = yes"))
  if question == 10:
    choice = choice + int(input("Do you think the goat is a male or female?\n 1 = female, 2 = men"))
  print(question)

if question == 10:
  if choice >= 10 and choice <= 15:
    print("Probably a female (Nanny).")
  if choice >15:
    print("Probabyl a male (Billy)")
  if choice <10:
    print("Probably a child")
