# %% [markdown]
# Farm merge valley is an activity in discord. The objective of the game is to merge 3 of the same object, which levels up to a new object. Some objects level up to 4. When they become level 4, they stop being mergeable and begin producing goods. These goods can be used to fulfill requests of deliveries on the farms, which give money. This money can be used to buy new land.
#
# You can visit your discord friends in the game, helping them with tasks on the farm for which you both are rewarded (this helping is sometimes called "collectivism" in politics).
#
# At the moment, there is land you can buy up to level 69.

# %%
while farm_merge_valley == active:
    play

# %%
farm_merge_valley = 'The Holy Grail'
farm_merge_valley_gif = 'fun'
status = 1
player = "Mittwochsberliner"
emotion = 'neutral'

if player == "dead":
    status = 1
else:
    status = 2

while status == 2:
    play(farm_merge_valley)
    while farm_merge_valley_gif == false:
        emotion = 'sad'
    else:
        emotion = 'happy'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10     status = 2
#      12 while status == 2:
# ---> 13     play(farm_merge_valley)
#      14     while farm_merge_valley_gif == false:
#      15         emotion = 'sad'
#
# NameError: name 'play' is not defined
