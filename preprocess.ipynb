# %%
import pandas as pd

df = pd.read_csv('../instagram_comments20250115_154508_0.csv')
# Out:
#                                                 url             comment_user  \
# 0                https://www.instagram.com/fiah_sa_          elisna_greyling
# 1             https://www.instagram.com/womenwhojam               annelesear
# 2              https://www.instagram.com/astacaplan             shalamandala
# 3  https://www.instagram.com/bridgehomelessrecovery         womens_power._dm
# 4       https://www.instagram.com/mokshavridhashram  adharshila_old_age_home
#
#                                     comment_user_url  \
# 0          https://www.instagram.com/elisna_greyling
# 1               https://www.instagram.com/annelesear
# 2             https://www.instagram.com/shalamandala
# 3         https://www.instagram.com/womens_power._dm
# 4  https://www.instagram.com/adharshila_old_age_home
#
#                comment_date  \
# 0  2024-04-28T15:58:08.000Z
# 1  2023-11-13T13:17:00.000Z
# 2  2024-01-06T15:27:24.000Z
# 3  2024-01-13T16:02:42.000Z
# 4  2024-02-29T10:24:43.000Z
#
# ...

# %%
df.head()
# Out:
#                                                 url             comment_user  \
# 0                https://www.instagram.com/fiah_sa_          elisna_greyling
# 1             https://www.instagram.com/womenwhojam               annelesear
# 2              https://www.instagram.com/astacaplan             shalamandala
# 3  https://www.instagram.com/bridgehomelessrecovery         womens_power._dm
# 4       https://www.instagram.com/mokshavridhashram  adharshila_old_age_home
#
#                                     comment_user_url  \
# 0          https://www.instagram.com/elisna_greyling
# 1               https://www.instagram.com/annelesear
# 2             https://www.instagram.com/shalamandala
# 3         https://www.instagram.com/womens_power._dm
# 4  https://www.instagram.com/adharshila_old_age_home
#
#                comment_date  \
# 0  2024-04-28T15:58:08.000Z
# 1  2023-11-13T13:17:00.000Z
# 2  2024-01-06T15:27:24.000Z
# 3  2024-01-13T16:02:42.000Z
# 4  2024-02-29T10:24:43.000Z
#
# ...
